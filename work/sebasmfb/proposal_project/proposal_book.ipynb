# %%
import numpy as np
import pandas as pd

from IPython.display import display, HTML
display(HTML("<style>.text_cell_render { font-family: 'Computer Modern', serif; }</style>"))
# Out:
# <style>.text_cell_render { font-family: 'Computer Modern', serif; }</style>

# %% [markdown]
# # Proposal Plan

# %% [markdown]
# <span style="font-size: 16px;">$\textbf{Plan}$: Follow up SMBHB candidates (identified with analyses of their SEDs and light curves) with time-series photometry (still have to decide between targeting rapid cadencing or long baseline. Depends on, say, detection of a possible self-lensing peak)</span>
#
# <span style="font-size: 16px;">$\textbf{Telescope}$: One of Las Cumbres Observatory's 1-meter telescope, as it is most aligned with the overarching goal of time-domain optical photometry</span>

# %% [markdown]
# <span style="font-size: 16px;">$\textbf{Draft}$: We expect supermassive black hole binaries (SMBHBs) are natural consequences under the prevailing galaxy evolution paradigm in which massive galaxies host SMBHs at their core and frequently merge with other galaxies. In this model, a series of dissipative interactions bring SMBHs in merging galaxies toward a common merger remnant. Observations of closely-separated dual active galactic nuclei (AGN) (~7 pc) anchor of the early frames of this picture, but the climactic final frames of a gravitationally-bound SMBHB remains undetected. Time-domain spectroscopic and photometric observations of AGN provide a promising avenue to resolve this gap and detect bound SMBHBs. Particularly, irregularities in AGN time-series spectra may indicate bulk orbital motion in a binary, and periodic variability in AGN light curves may reveal uniquely-binary signatures of brightness modulation. By jointly analyzing existing catalogs of AGN spectra and light curves, we have culled a sample of 10 promising SMBHB candidates whose status as such should be sufficiently constrained with follow-up time-series photometry. Particularly, we request X amount of time from $\textbf{Las Cumbres Observatory's 1-meter telescope}$ dedicated to photometric observations of the candidates at dates listed in table Y.</span>
#
# <span style="font-size: 16px;">The Dark Energy Spectroscopic Instrument (DESI) has observed the spectra of nearly 100,000 quasars over a wavelength range spanning the near-UV, optical and near-IR bands. Irregularities in AGN spectra--among them, broad line velocity shifts and double-peaked broad line emitters--may indicate bulk orbital motion in a binary (De Rosa et al. 2019). By combing the DESI catalog of AGN spectra, researchers (?) have identified X SMBHB candidates...</span>
